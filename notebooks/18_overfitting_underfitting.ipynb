# %% [markdown]
# # Overfitting and Underfitting

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# Lets make a little test dataset. Our initial function is just a cosine wave with some noise added on top

# %%
def true_fun(X):
    return np.cos(1.5 * np.pi * X)


np.random.seed(0)

n_samples = 30

X = np.sort(np.random.rand(n_samples))
y = true_fun(X) + np.random.randn(n_samples) * 0.1

plt.plot(X, y)
plt.plot(X, true_fun(X))

plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=19)

# %% [markdown]
# Training a simple linear regressor on this data does not perform well, as weve already seen in last notebook.

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error

degree = 1
polynomial_features = PolynomialFeatures(degree=degree, include_bias=False)
linear_regression = LinearRegression()
pipeline = Pipeline(
    [
        ("polynomial_features", polynomial_features),
        ("linear_regression", linear_regression),
    ]
)

pipeline.fit(X_train[:, np.newaxis], y_train)

# X_base = np.linspace(0, 1, 100)
y_pred = pipeline.predict(X_test[:, np.newaxis])

plt.plot(X_test[:, np.newaxis], y_pred, label="Model")
plt.plot(np.linspace(0, 1, 100), true_fun(np.linspace(0, 1, 100)), label="True function")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

mean_absolute_percentage_error(y_pred, y_test)
# Out:
# 0.8857790775930177

# %% [markdown]
# Using the polynomials trick from last jupyter notebook we can help our model to capture the function a bit better. Lets put what we did above and the ploynomial creation in a function so we can call it with different degrees.

# %%
def linear_regression_with_polynomials_of_degree(degree):
    polynomial_features = PolynomialFeatures(degree=degree, include_bias=False)
    linear_regression = LinearRegression()
    pipeline = Pipeline(
        [
            ("polynomial_features", polynomial_features),
            ("linear_regression", linear_regression),
        ]
    )
    pipeline.fit(X[:, np.newaxis], y)

    X_test = np.linspace(0, 1, 100)
    y_pred = pipeline.predict(X_test[:, np.newaxis])
    plt.plot(X_test, y_pred, label="Model")
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.legend()
    plt.show()

# %% [markdown]
# Calling this with degree = 1  leads to the same model as above.

# %%
linear_regression_with_polynomials_of_degree(1)

# %% [markdown]
# How about degree = 2?
# This is looking better, but we are still underfitting, meaning that our model can not grasp the complexity of the true function.

# %%
linear_regression_with_polynomials_of_degree(2)

# %% [markdown]
# How about degree = 4?

# %%
linear_regression_with_polynomials_of_degree(4)

# %% [markdown]
# Almost perfect, but what happens if we start to increase the number of degrees further?

# %%
linear_regression_with_polynomials_of_degree(12)

# %% [markdown]
# The output above starts having similarities with the noise in the original inputs. We are now significantly overfitting. While the model captures the original trainingset in moore and more detail, it actually is getting worse in modelling the true function.

# %%
plt.plot(X, y)
plt.show()

# %% [markdown]
# **Exercise** *: What happens if we go beyond our trainng sets range (to the left or right, or both).

# %% [markdown]
# **Exercise** *: How can we get some indication of our models overfitting on the training data?

# %% [markdown]
# **Exercise** **: Use a regression metric of your choosing and demonstrate how you can show that a model is overfitting.
