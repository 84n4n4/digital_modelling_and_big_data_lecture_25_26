# %% [markdown]
# # Assignment 2
#
# Perform the tasks detailed in the Todo's
# Do not change the methods names and signature (unless explicitely asked to do so in the todo)
# You are free to add new functions as long as they do not shadow existing function names.
#
# IF ALREADY KNOW PYTHON AND THIS IS BORING TO YOU:
# '\*\*\*' Version of this:
# Implement all tasks in polars (https://docs.pola.rs/) instead. '\*\*\*\*': Bonus, use timeit (https://docs.python.org/3/library/timeit.html) and determine if and by how much it is faster than the pandas version.

# %%
import pandas
import numpy as np

# %%
# Todo: create a sine wave USING NUMPY given a start and end value and given step size:
def create_sine_wave(start, stop, step_size):
    return np.sin(np.arange(start, stop, step_size))

print(create_sine_wave(0, 10, 0.1))
# Out:
# [ 0.          0.09983342  0.19866933  0.29552021  0.38941834  0.47942554
#   0.56464247  0.64421769  0.71735609  0.78332691  0.84147098  0.89120736
#   0.93203909  0.96355819  0.98544973  0.99749499  0.9995736   0.99166481
#   0.97384763  0.94630009  0.90929743  0.86320937  0.8084964   0.74570521
#   0.67546318  0.59847214  0.51550137  0.42737988  0.33498815  0.23924933
#   0.14112001  0.04158066 -0.05837414 -0.15774569 -0.2555411  -0.35078323
#  -0.44252044 -0.52983614 -0.61185789 -0.68776616 -0.7568025  -0.81827711
#  -0.87157577 -0.91616594 -0.95160207 -0.97753012 -0.993691   -0.99992326
#  -0.99616461 -0.98245261 -0.95892427 -0.92581468 -0.88345466 -0.83226744
#  -0.77276449 -0.70554033 -0.63126664 -0.55068554 -0.46460218 -0.37387666
#  -0.2794155  -0.1821625  -0.0830894   0.0168139   0.1165492   0.21511999
#   0.31154136  0.40484992  0.49411335  0.57843976  0.6569866   0.72896904
#   0.79366786  0.85043662  0.8987081   0.93799998  0.96791967  0.98816823
#   0.99854335  0.99894134  0.98935825  0.96988981  0.94073056  0.90217183
#   0.85459891  0.79848711  0.7343971   0.66296923  0.58491719  0.50102086
#   0.41211849  0.31909836  0.22288991  0.12445442  0.02477543 -0.07515112
#  -0.17432678 -0.27176063 -0.36647913 -0.45753589]

# %%
# Todo - Sort the dataframe df by height in ascending order and return the sorted dataframe
def sort_by_height(df):
    return df.sort_values(by='Height', ascending=True)

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Edward', 'Fiona', 'George', 'Hannah', 'Ivan', 'Julia'],
    'Height': [165, 170, 175, 160, 180, 155, 168, 172, 178, 169],
    'Age': [25, 32, 40, 22, 28, 30, 35, 26, 41, 29],
    'YearsStudying': [2, 5, 4, 1, 4, 4, 7, 3, 6, 2],
    'Sex': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female']
}

dframe = pandas.DataFrame(data)

print(sort_by_height(dframe))
# Out:
#       Name  Height  Age  YearsStudying     Sex
# 5    Fiona     155   30              4  Female
# 3    Diana     160   22              1  Female
# 0    Alice     165   25              2  Female
# 6   George     168   35              7    Male
# 9    Julia     169   29              2  Female
# 1      Bob     170   32              5    Male
# 7   Hannah     172   26              3  Female
# 2  Charlie     175   40              4    Male
# 8     Ivan     178   41              6    Male
# 4   Edward     180   28              4    Male

# %%
# Todo - Slice the dataframe to only contain the Male students.
def only_male_students(df):
    return df[df['Sex'] == 'Male']

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Edward', 'Fiona', 'George', 'Hannah', 'Ivan', 'Julia'],
    'Height': [165, 170, 175, 160, 180, 155, 168, 172, 178, 169],
    'Age': [25, 32, 40, 22, 28, 30, 35, 26, 41, 29],
    'YearsStudying': [2, 5, 4, 1, 4, 4, 7, 3, 6, 2],
    'Sex': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female']
}

dframe = pandas.DataFrame(data)

print(only_male_students(dframe))
# Out:
#       Name  Height  Age  YearsStudying   Sex
# 1      Bob     170   32              5  Male
# 2  Charlie     175   40              4  Male
# 4   Edward     180   28              4  Male
# 6   George     168   35              7  Male
# 8     Ivan     178   41              6  Male

# %%
# Todo - Slice the dataframe to only contain the Male students taller than 170cm.
def only_tall_male_students(df):
    return df[(df['Sex'] == 'Male') & (df['Height'] > 170)]


data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Edward', 'Fiona', 'George', 'Hannah', 'Ivan', 'Julia'],
    'Height': [165, 170, 175, 160, 180, 155, 168, 172, 178, 169],
    'Age': [25, 32, 40, 22, 28, 30, 35, 26, 41, 29],
    'YearsStudying': [2, 5, 4, 1, 4, 4, 7, 3, 6, 2],
    'Sex': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female']
}

dframe = pandas.DataFrame(data)

print(only_tall_male_students(dframe))
# Out:
#       Name  Height  Age  YearsStudying   Sex
# 2  Charlie     175   40              4  Male
# 4   Edward     180   28              4  Male
# 8     Ivan     178   41              6  Male

# %%
# Todo - Given that now is 2024, create a new column that contains the year when the students started when they have
#  been studying for 'YearsStudying'. Write the result in a new column named 'YearStarted' and return the new dataframe.
def year_started(df):
    now = 2024
    df['YearStarted'] = now - df['YearsStudying']
    return df

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Edward', 'Fiona', 'George', 'Hannah', 'Ivan', 'Julia'],
    'Height': [165, 170, 175, 160, 180, 155, 168, 172, 178, 169],
    'Age': [25, 32, 40, 22, 28, 30, 35, 26, 41, 29],
    'YearsStudying': [2, 5, 4, 1, 4, 4, 7, 3, 6, 2],
    'Sex': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female']
}

dframe = pandas.DataFrame(data)

print(year_started(dframe))
# Out:
#       Name  Height  Age  YearsStudying     Sex  YearStarted
# 0    Alice     165   25              2  Female         2022
# 1      Bob     170   32              5    Male         2019
# 2  Charlie     175   40              4    Male         2020
# 3    Diana     160   22              1  Female         2023
# 4   Edward     180   28              4    Male         2020
# 5    Fiona     155   30              4  Female         2020
# 6   George     168   35              7    Male         2017
# 7   Hannah     172   26              3  Female         2021
# 8     Ivan     178   41              6    Male         2018
# 9    Julia     169   29              2  Female         2022

# %%
# Todo - Group the dataframe by sex and return means of age, height, and years studying. (google pandas 'groupby')
#  returned value must be a dataframe.
def group_means(df):
    return df.drop(columns='Name').groupby(['Sex']).mean()


data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Edward', 'Fiona', 'George', 'Hannah', 'Ivan', 'Julia'],
    'Height': [165, 170, 175, 160, 180, 155, 168, 172, 178, 169],
    'Age': [25, 32, 40, 22, 28, 30, 35, 26, 41, 29],
    'YearsStudying': [2, 5, 4, 1, 4, 4, 7, 3, 6, 2],
    'Sex': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female']
}

dframe = pandas.DataFrame(data)

print(group_means(dframe))
# Out:
#         Height   Age  YearsStudying
# Sex
# Female   164.2  26.4            2.4
# Male     174.2  35.2            5.2

# %%
# Todo - Combine the two dataframes into a single one by concatenation (direction should be clear,
#  the number of columns must not change) and return the new dataframe
def concat_dataframes(df_a, df_b):
    return pandas.concat([df_a, df_b], ignore_index=True)


data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Edward', 'Fiona', 'George', 'Hannah', 'Ivan', 'Julia'],
    'Height': [165, 170, 175, 160, 180, 155, 168, 172, 178, 169],
    'Age': [25, 32, 40, 22, 28, 30, 35, 26, 41, 29],
    'YearsStudying': [2, 5, 4, 1, 4, 4, 7, 3, 6, 2],
    'Sex': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female']
}

dframe_a = pandas.DataFrame(data)

data_2 = {
    'Name': ['Kevin', 'Lewis', 'Martha'],
    'Height': [195, 172, 158],
    'Age': [22, 27, 29],
    'YearsStudying': [1, 3, 4],
    'Sex': ['Male', 'Male', 'Female']
}

dframe_b = pandas.DataFrame(data_2)

print(concat_dataframes(dframe_a, dframe_b))
# Out:
#        Name  Height  Age  YearsStudying     Sex
# 0     Alice     165   25              2  Female
# 1       Bob     170   32              5    Male
# 2   Charlie     175   40              4    Male
# 3     Diana     160   22              1  Female
# 4    Edward     180   28              4    Male
# 5     Fiona     155   30              4  Female
# 6    George     168   35              7    Male
# 7    Hannah     172   26              3  Female
# 8      Ivan     178   41              6    Male
# 9     Julia     169   29              2  Female
# 10    Kevin     195   22              1    Male
# 11    Lewis     172   27              3    Male
# 12   Martha     158   29              4  Female

# %%
# Todo - Fill the missing values ('NaN') in the dataframe with 0.
def fill_missing_values(df):
    return df.fillna(0)

data_3 = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Edward', 'Fiona', 'George', 'Hannah', 'Ivan', 'Julia'],
    'Height': [165, np.nan, 175, 160, 180, 155, 168, 172, 178, 169],
    'Age': [25, 32, 40, 22, np.nan, 30, 35, 26, 41, 29],
    'YearsStudying': [2, 5, np.nan, 1, 4, 4, 7, np.nan, 6, 2],
    'Sex': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female']
}

dframe_3 = pandas.DataFrame(data_3)

print(fill_missing_values(dframe_3))
# Out:
#       Name  Height   Age  YearsStudying     Sex
# 0    Alice   165.0  25.0            2.0  Female
# 1      Bob     0.0  32.0            5.0    Male
# 2  Charlie   175.0  40.0            0.0    Male
# 3    Diana   160.0  22.0            1.0  Female
# 4   Edward   180.0   0.0            4.0    Male
# 5    Fiona   155.0  30.0            4.0  Female
# 6   George   168.0  35.0            7.0    Male
# 7   Hannah   172.0  26.0            0.0  Female
# 8     Ivan   178.0  41.0            6.0    Male
# 9    Julia   169.0  29.0            2.0  Female

# %%
# Todo - convert time to datetime and set the index to be that datetime (and do not have two time columns in the end,
#  returned dataframe should have only the time index and the 'measurement_a' and 'measurement_a' columns.
def make_datetime_index(df):
    df['time'] = pandas.to_datetime(df['time'])
    df = df.set_index('time', drop=True)
    return df

data_time = {
    'time': ['2024-10-20T01:00+00:00', '2024-10-20T05:34+00:00', '2024-10-20T07:12+00:00',
             '2024-10-20T12:20+00:00'],
    'measurement_a': [1, 3, 8, 23],
    'measurement_b': [34, 23, 12, 33]
}

dframe_time = pandas.DataFrame(data_time)

print(dframe_time)
print(make_datetime_index(dframe_time))
# Out:
#                      time  measurement_a  measurement_b
# 0  2024-10-20T01:00+00:00              1             34
# 1  2024-10-20T05:34+00:00              3             23
# 2  2024-10-20T07:12+00:00              8             12
# 3  2024-10-20T12:20+00:00             23             33
#                            measurement_a  measurement_b
# time
# 2024-10-20 01:00:00+00:00              1             34
# 2024-10-20 05:34:00+00:00              3             23
# 2024-10-20 07:12:00+00:00              8             12
# 2024-10-20 12:20:00+00:00             23             33

# %%
# Todo - calculate the difference between each measurement and the last measurement and put it in a new
#  column namend 'difference'. (since you cannot do this for the first one, set the value to np.nan there.)
def difference_between_measurements(df):
    df['diff_a'] = df['measurement_a'].diff()
    df['diff_b'] = df['measurement_b'].diff()
    return df

data_measurements = {
    'measurement_a': [1, 3, 8, 23],
    'measurement_b': [34, 23, 12, 33]
}

dframe_measurements = pandas.DataFrame(data_measurements)

# print(dframe_measurements)
print(difference_between_measurements(dframe_measurements))
# Out:
#    measurement_a  measurement_b  diff_a  diff_b
# 0              1             34     NaN     NaN
# 1              3             23     2.0   -11.0
# 2              8             12     5.0   -11.0
# 3             23             33    15.0    21.0

# %% [markdown]
# ## TAWES part

# %% [markdown]
# **Task** Load the TAWES vienna csv as a pandas dataframe.

# %%
import pandas

# load the dataset from ../../data/tawes/Messstationen Tagesdaten v2 Datensatz_18730101_19921231_wien.csv
df = pandas.read_csv('../../data/tawes/Messstationen Tagesdaten v2 Datensatz_18730101_19921231_wien.csv')

# %% [markdown]
# **Task** Change the index to a datetime index using the 'time' column.

# %%
# see 11_pandas_tawes.ipynb or 12_data_visualization.ipynb
df['time'] = pandas.to_datetime(df['time'], utc=True)
df = df.set_index('time', drop=True)
df.head()
# Out:
#                            station  tlmax  tlmin  tl_mittel  cglo_j   rr  \
# time
# 1873-01-02 00:00:00+00:00     5901    1.0    0.0        0.5     NaN  0.3
# 1873-01-03 00:00:00+00:00     5901    6.2    0.3        3.3     NaN -1.0
# 1873-01-04 00:00:00+00:00     5901    4.9    0.0        2.5     NaN -1.0
# 1873-01-05 00:00:00+00:00     5901    2.7   -1.6        0.6     NaN -1.0
# 1873-01-06 00:00:00+00:00     5901    8.6    0.0        4.3     NaN -1.0
#
#                            vv_mittel  p_mittel
# time
# 1873-01-02 00:00:00+00:00        0.2     995.7
# 1873-01-03 00:00:00+00:00        1.0    1000.6
# 1873-01-04 00:00:00+00:00        0.2    1003.6
# 1873-01-05 00:00:00+00:00        0.6    1000.3
# 1873-01-06 00:00:00+00:00        1.5    1003.6

# %% [markdown]
# **Task** Resample the dataframe to yearly means.

# %%
df = df.resample('1YE').mean()
df.head()
# Out:
#                            station      tlmax     tlmin  tl_mittel  cglo_j  \
# time
# 1873-12-31 00:00:00+00:00   5901.0  14.374176  6.106319  10.259615     NaN
# 1874-12-31 00:00:00+00:00   5901.0  13.273425  5.082466   9.191781     NaN
# 1875-12-31 00:00:00+00:00   5901.0  12.427123  4.384932   8.419178     NaN
# 1876-12-31 00:00:00+00:00   5901.0  12.718306  4.960929   8.856011     NaN
# 1877-12-31 00:00:00+00:00   5901.0  13.398904  5.323014   9.379452     NaN
#
#                                  rr  vv_mittel    p_mittel
# time
# 1873-12-31 00:00:00+00:00  0.792033   2.416758  992.007967
# 1874-12-31 00:00:00+00:00  1.112329   2.615890  992.233425
# 1875-12-31 00:00:00+00:00  1.254521   2.513151  992.263562
# 1876-12-31 00:00:00+00:00  1.321858   2.388251  990.894521
# 1877-12-31 00:00:00+00:00  1.010685   2.195616  991.103846

# %% [markdown]
# **Task** Slice/Filter the dataframe to only contain dates between 1890 and 1990

# %%
df = df['1890-01-01':'1990-12-31']

# %% [markdown]
# **Task** Plot the yearly mean temperatures ('tl_mittel') on the y axis and time on the x axis.

# %%
import matplotlib.pyplot as plt

df['tl_mittel'].plot()
plt.show()
